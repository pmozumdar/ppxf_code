# %%
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util
from specim.specfuncs import spec1d
import numpy as np
import matplotlib.pyplot as plt
import glob
from random import sample
import pandas as pd
import seaborn as sn
import pm_veldis_util as vd
from collections import Counter
from keckcode.deimos import deimosmask1d

# %%
coadded_spectra = deimosmask1d.DeimosMask1d('../galaxy_spectra/0712m4-blue-coadd_latest.fits')
# Out:
# Reading 18 spectra from:
#   ../galaxy_spectra/0712m4-blue-coadd_latest.fits

# %%
specid = [] #np.zeros(coadded_spectra.nspec)
info = coadded_spectra.slitinfo
#print(info)
for i in range(coadded_spectra.nspec):
    spec_id = '%d_%d_%d_%d' % (info['det'][i], info['slitid'][i], info['objid'][i], info['spatloc'][i])
    specid.append(spec_id)
    print(spec_id)
# Out:
# 1_584_1_588
# 1_713_1_695
# 1_999_1_1021
# 1_1115_1_1077
# 1_1310_1_1342
# 1_1437_1_1429
# 1_1537_1_1535
# 1_1708_1_1702
# 1_1901_1_1857
# 2_121_1_100
# 2_305_1_256
# 2_305_2_308
# 2_533_1_595
# 2_777_1_760
# 2_908_1_913
# 2_1045_1_1034
# 2_1288_1_1264
# 2_1465_1_1461

# %% [markdown]
# ## The first one is a spectrum of a galaxy at redshift around 0.296 based on Ca K+H lines

# %%
# %matplotlib notebook

for i in range(len(specid)):
    print('spec_id : %s' %specid[i])
    coadded_spectra[specid[i]].smooth(7)
    coadded_spectra[specid[i]].mark_lines('abs', z=0.405, usesmooth=True)
#plt.figure(figsize=(50,50))
#lines={'em' : True, 'strongem' : True}, index=specid[i]
# Out:
# spec_id : 1_584_1_588
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Fe II         2587.00       3634.74
# Fe II         2600.00       3653.00
# Fe II         2750.30       3864.17
# Mg II         2795.53       3927.72
# Mg II         2802.71       3937.81
# Mg I          2852.00       4007.06
# H-kappa       3750.00       5268.75
# [Fe VII]      3761.40       5284.77
# H-iota        3770.00       5296.85
# H-theta       3797.00       5334.78
# H-eta         3835.00       5388.18
# CN bandhd     3883.00       5455.61
# CaII K        3933.67       5526.81
# CaII H        3968.47       5575.70
# H-delta       4101.00       5761.90
#
# spec_id : 1_713_1_695
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Line        lambda_rest  lambda_obs
# ----------  -----------  -----------
# Fe II         2375.00       3336.88
# Fe II         2383.00       3348.12
# ...

# %% [markdown]
# ## The second one seems like a stellar spectra

# %%
print('spec_id : %s' %specid[1])
coadded_spectra[specid[1]].smooth(7)
coadded_spectra[specid[1]].mark_lines('abs', z=0, usesmooth=True)

# %% [markdown]
# ## This one seems like a stellar spectra but not sure

# %%
print('spec_id : %s' %specid[2])
coadded_spectra[specid[2]].smooth(31)
coadded_spectra[specid[2]].mark_lines('abs', z=0, usesmooth=True)

# %% [markdown]
# ## This is a galaxy spectra at redshift around 0.3 based on Ca K+H. Ca K line fits for z=0.305 and Ca H  fits at z=0.298 and however both of them does not fit simultaneously at any redshift. May be some error in wavelength calibration because does not seem like smoothing effect.

# %%
print('spec_id : %s' %specid[3])
coadded_spectra[specid[3]].smooth(5)
coadded_spectra[specid[3]].mark_lines('abs', z=0.309, usesmooth=True)

# %%
coadded_spectra_red = deimosmask1d.DeimosMask1d('../galaxy_spectra/0712m4_coadd.fits')

# %%
specid_red = [] #np.zeros(coadded_spectra.nspec)
info = coadded_spectra_red.slitinfo
#print(info)
for i in range(coadded_spectra_red.nspec):
    spec_id = '%d_%d_%d_%d' % (info['det'][i], info['slitid'][i], info['objid'][i], info['spatloc'][i])
    specid_red.append(spec_id)
    print(spec_id)

# %%
for i in range(len(specid_red)):
    print('spec_id : %s' %specid_red[i])
    coadded_spectra_red[specid_red[i]].smooth(7)
    coadded_spectra_red[specid_red[i]].mark_lines('abs', z=0.405, usesmooth=True)
#plt.figure(figsize=(50,50))
#lines={'em' : True, 'strongem' : True}, index=specid[i]

# %%
full_data = spec1d.Spec1d('../galaxy_spectra/0712m4_coadd.fits', informat='fitstab')

# %%
full_data.plot()
full_data.mark_lines('abs', z=0.405)

# %%
data = spec1d.Spec1d('../galaxy_spectra/0712m4_coadd.fits', informat='fitstab', trimsec=[0, 4000])

# %%
data.plot()
data.mark_lines('abs', z=0.405)

# %%
# %matplotlib notebook
data.smooth(11)
data.mark_lines('abs', z=0.29, usesmooth=True)

# %%
full_data_blue = spec1d.Spec1d('../galaxy_spectra/0712m4_coadd-blue.fits', informat='fitstab',
                               trimsec=[4, 4096])

# %%
full_data_blue.plot()
full_data_blue.mark_lines('abs', z=0.305)

# %%
full_data_blue.smooth(7)
full_data_blue.mark_lines('abs', z=0.302, usesmooth=True)

# %%
plt.plot(full_data_blue[0][:], full_data_blue[1][:]/np.sqrt(full_data_blue[2][:]))
plt.show()

# %%
print(full_data_blue[2][:])
